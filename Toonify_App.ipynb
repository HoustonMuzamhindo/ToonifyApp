# %% [raw]
# ---
# title: Cartoon your pictures using Machine Learning!
# description: Experience Machine Learning by creating a cartoon version of your picture
# show-code: False
# params:
#     image_path:
#         input: file
#         label: Please upload your picture
# ---

# %%
import os
import torch
from PIL import Image
import warnings
warnings.filterwarnings("ignore", category=UserWarning)

# %%
#image_path = "photo.jpg"

# %%
model = torch.hub.load("bryandlee/animegan2-pytorch:main", "generator", pretrained = "paprika")
face2paint = torch.hub.load("bryandlee/animegan2-pytorch:main", "face2paint", size = 512)
# Out:
# Using cache found in C:\Users\hp/.cache\torch\hub\bryandlee_animegan2-pytorch_main
# Using cache found in C:\Users\hp/.cache\torch\hub\bryandlee_animegan2-pytorch_main

# %%
#function to return the cartoonised image
#def toonify(img):
#    out = face2paint(model, img)
#    return out

# %%
#load the image to the toonified
#im = Image.open(image_path)

# %%
#toonify image
#toonify(im)
# Out:
# <PIL.Image.Image image mode=RGB size=512x512 at 0x25B45DDE670>
